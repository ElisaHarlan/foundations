# %% [markdown]
# # Homework 5, Part 2: Answer questions with pandas
#
# **Use the Excel file to answer the following questions.** This is a little more typical of what your data exploration will look like with pandas.

# %% [markdown]
# ## 0) Setup
#
# Import pandas **with the correct name** and set `matplotlib` to always display graphics in the notebook.

# %%
import pandas as pd
# %matplotlib inline

# %% [markdown]
# ## 1) Reading in an Excel file
#
# Use pandas to read in the `richpeople.xlsx` Excel file, saving it as a variable with the "correct" name. You will use `read_excel` instead of `read_csv`, *but you'll also need to install a new library*.

# %%
df = pd.read_excel("richpeople.xlsx")

# %% [markdown]
# ## 2) Checking your data
#
# Display the number of rows and columns in your data. Also display the names and data types of each column.

# %%
df.head()
# Out:
#    year                          name  rank           citizenship countrycode  \
# 0  2014          A. Jerrold Perenchio   663         United States         USA
# 1  2014            Abdulla Al Futtaim   687  United Arab Emirates         ARE
# 2  2014  Abdulla bin Ahmad Al Ghurair   305  United Arab Emirates         ARE
# 3  2014             Abdullah Al Rajhi   731          Saudi Arabia         SAU
# 4  2014              Abdulsamad Rabiu  1372               Nigeria         NGA
#
#    networthusbillion   selfmade         typeofwealth gender   age   ...     \
# 0                2.6  self-made            executive   male  83.0   ...
# 1                2.5  inherited            inherited   male   NaN   ...
# 2                4.8  inherited            inherited   male   NaN   ...
# 3                2.4  self-made    self-made finance   male   NaN   ...
# 4                1.2  self-made  founder non-finance   male  54.0   ...
#
#      relationshiptocompany foundingdate gdpcurrentus  \
# 0  former chairman and CEO       1955.0          NaN
# 1                 relation       1930.0          NaN
# 2                 relation       1960.0          NaN
# 3                  founder       1957.0          NaN
# 4                  founder       1988.0          NaN
#
#               sourceofwealth                                           notes  \
# 0      television, Univision  represented Marlon Brando and Elizabeth Taylor
# 1  auto dealers, investments    company split between him and cousin in 2000
# 2                diversified                           inherited from father
# 3                    banking                                             NaN
# 4       sugar, flour, cement                                             NaN
#
#    notes2                                           source  \
# 0     NaN     http://en.wikipedia.org/wiki/Jerry_Perenchio
# 1     NaN    http://en.wikipedia.org/wiki/Al-Futtaim_Group
# 2     NaN    http://en.wikipedia.org/wiki/Al-Ghurair_Group
# 3     NaN       http://en.wikipedia.org/wiki/Al-Rajhi_Bank
# 4     NaN  http://www.forbes.com/profile/abdulsamad-rabiu/
#
#                                             source_2  \
# 0  http://www.forbes.com/profile/a-jerrold-perenc...
# 1  http://www.al-futtaim.ae/content/groupProfile.asp
# 2      http://www.alghurair.com/about-us/our-history
# 3  http://www.alrajhibank.com.sa/ar/investor-rela...
# 4  http://www.bloomberg.com/research/stocks/priva...
#
#                                             source_3 source_4
# 0  COLUMN ONE; A Hollywood Player Who Owns the Ga...      NaN
# 1                                                NaN      NaN
# 2                                                NaN      NaN
# 3  http://www.alrajhibank.com.sa/ar/about-us/page...      NaN
# 4                                                NaN      NaN
#
# [5 rows x 30 columns]

# %%
df.shape
# Out:
# (1653, 30)

# %%
df.columns
# Out:
# Index(['year', 'name', 'rank', 'citizenship', 'countrycode',
#        'networthusbillion', 'selfmade', 'typeofwealth', 'gender', 'age',
#        'industry', 'IndustryAggregates', 'region', 'north',
#        'politicalconnection', 'founder', 'generationofinheritance', 'sector',
#        'company', 'companytype', 'relationshiptocompany', 'foundingdate',
#        'gdpcurrentus', 'sourceofwealth', 'notes', 'notes2', 'source',
#        'source_2', 'source_3', 'source_4'],
#       dtype='object')

# %%
df.dtypes
# Out:
# year                         int64
# name                        object
# rank                         int64
# citizenship                 object
# countrycode                 object
# networthusbillion          float64
# selfmade                    object
# typeofwealth                object
# gender                      object
# age                        float64
# industry                    object
# IndustryAggregates          object
# region                      object
# north                        int64
# politicalconnection        float64
# founder                      int64
# generationofinheritance     object
# sector                      object
# company                     object
# companytype                 object
# relationshiptocompany       object
# foundingdate               float64
# gdpcurrentus               float64
# sourceofwealth              object
# notes                       object
# notes2                      object
# source                      object
# source_2                    object
# source_3                    object
# source_4                    object
# dtype: object

# %% [markdown]
# ## 3) Who are the top 10 richest billionaires? Use the `networthusbillion` column.

# %%
df.sort_values(by="networthusbillion", ascending=False)
# Out:
#       year                              name  rank     citizenship  \
# 184   2014                        Bill Gates     1   United States
# 226   2014                  Carlos Slim Helu     2          Mexico
# 79    2014                    Amancio Ortega     3           Spain
# 1562  2014                    Warren Buffett     4   United States
# 862   2014                     Larry Ellison     5   United States
# 339   2014                        David Koch     6   United States
# 247   2014                      Charles Koch     6   United States
# 1364  2014                   Sheldon Adelson     8   United States
# 280   2014                    Christy Walton     9   United States
# 724   2014                        Jim Walton    10   United States
# 918   2014               Liliane Bettencourt    11          France
# 1395  2014                    Stefan Persson    12          Sweden
# 67    2014                      Alice Walton    13   United States
# 1322  2014                  S. Robson Walton    14   United States
# 173   2014                   Bernard Arnault    15          France
# 1031  2014                 Michael Bloomberg    16   United States
# 863   2014                        Larry Page    17   United States
# 700   2014                        Jeff Bezos    18   United States
# 1354  2014                       Sergey Brin    19   United States
# 906   2014                       Li Ka-shing    20       Hong Kong
# 1004  2014                   Mark Zuckerberg    21   United States
# 1056  2014                   Michele Ferrero    22           Italy
# 815   2014                     Karl Albrecht    23         Germany
# 70    2014                     Aliko Dangote    23         Nigeria
# 216   2014                        Carl Icahn    25   United States
# 508   2014                      George Soros    26   United States
# 349   2014                     David Thomson    27          Canada
# 954   2014                       Lui Che Woo    28       Hong Kong
# 365   2014                    Dieter Schwarz    29         Germany
# 1206  2014  Prince Alwaleed Bin Talal Alsaud    30    Saudi Arabia
# ...    ...                               ...   ...             ...
# 920   2014      Lim Hariyanto Wijaya Sarwono  1565       Indonesia
# 1086  2014                  Monika Schoeller  1565         Germany
# 111   2014                   Andrew Gotianun  1565     Philippines
# 156   2014                       B.R. Shetty  1565           India
# 82    2014                           An Kang  1565           China
# 1310  2014                      Rostam Azizi  1565        Tanzania
# 1497  2014                        Tory Burch  1565   United States
# 209   2014                     C. James Koch  1565   United States
# 371   2014                     Ding Shizhong  1565           China
# 923   2014                   Lin Ming-Hsiung  1565          Taiwan
# 485   2014                           Fu Kwan  1565           China
# 376   2014                    Dmitry Korzhev  1565          Russia
# 727   2014                  Jitendra Virwani  1565           India
# 380   2014                   Dmitry Troitsky  1565          Russia
# 1609  2014                         Yang Keng  1565           China
# 195   2014                     Brian Higgins  1565   United States
# 698   2014                      Jeanine Dick  1565          France
# 1398  2014            Stefan von Holtzbrinck  1565         Germany
# 1336  2014                      Sara Blakely  1565   United States
# 636   2014                          Ina Chan  1565       Hong Kong
# 936   2014                      Liu Xiaomeng  1565           China
# 567   2014                 Harindarpal Banga  1565           India
# 456   2014                     Feng Hailiang  1565           China
# 539   2014                    Graham Kirkham  1565  United Kingdom
# 891   2014                      Leon Charney  1565   United States
# 1598  2014                          Wu Xiong  1565           China
# 1554  2014                       Wang Muqing  1565           China
# 1596  2014                       Wu Chung-Yi  1565          Taiwan
# 904   2014                        Li Denghai  1565           China
# 370   2014                       Ding Shijia  1565           China
#
#      countrycode  networthusbillion   selfmade              typeofwealth  \
# 184          USA               76.0  self-made       founder non-finance
# 226          MEX               72.0  self-made  privatized and resources
# 79           ESP               64.0  self-made       founder non-finance
# 1562         USA               58.2  self-made       founder non-finance
# 862          USA               48.0  self-made       founder non-finance
# 339          USA               40.0  inherited                 inherited
# 247          USA               40.0  inherited                 inherited
# 1364         USA               38.0  self-made         self-made finance
# 280          USA               36.7  inherited                 inherited
# 724          USA               34.7  inherited                 inherited
# 918          FRA               34.5  inherited                 inherited
# 1395         SWE               34.4  inherited                 inherited
# 67           USA               34.3  inherited                 inherited
# 1322         USA               34.2  inherited                 inherited
# 173          FRA               33.5  self-made       founder non-finance
# 1031         USA               33.0  self-made       founder non-finance
# 863          USA               32.3  self-made       founder non-finance
# 700          USA               32.0  self-made       founder non-finance
# 1354         USA               31.8  self-made       founder non-finance
# 906          HKG               31.0  self-made         self-made finance
# 1004         USA               28.5  self-made       founder non-finance
# 1056         ITA               26.5  self-made                 executive
# 815          DEU               25.0  self-made                 executive
# 70           NGA               25.0  self-made       founder non-finance
# 216          USA               24.5  self-made         self-made finance
# 508          USA               23.0  self-made         self-made finance
# 349          CAN               22.6  inherited                 inherited
# 954          HKG               22.0  self-made         self-made finance
# 365          DEU               21.1  inherited                 inherited
# 1206         SAU               20.4  self-made  privatized and resources
# ...          ...                ...        ...                       ...
# 920          IDN                1.0  self-made  privatized and resources
# 1086         DEU                1.0  inherited                 inherited
# 111          PHL                1.0  self-made         self-made finance
# 156          IND                1.0  self-made       founder non-finance
# 82           CHN                1.0  self-made       founder non-finance
# 1310         TZA                1.0  self-made                 executive
# 1497         USA                1.0  self-made       founder non-finance
# 209          USA                1.0  self-made       founder non-finance
# 371          CHN                1.0  self-made                 executive
# 923       Taiwan                1.0  self-made  privatized and resources
# 485          CHN                1.0  self-made         self-made finance
# 376          RUS                1.0  self-made       founder non-finance
# 727          IND                1.0  self-made         self-made finance
# 380          RUS                1.0  self-made       founder non-finance
# 1609         CHN                1.0  self-made         self-made finance
# 195          USA                1.0  self-made         self-made finance
# 698          FRA                1.0  inherited                 inherited
# 1398         DEU                1.0  inherited                 inherited
# 1336         USA                1.0  self-made       founder non-finance
# 636          HKG                1.0  inherited                 inherited
# 936          CHN                1.0  self-made                 executive
# 567          IND                1.0  self-made  privatized and resources
# 456          CHN                1.0  self-made       founder non-finance
# 539          GBR                1.0  self-made       founder non-finance
# 891          USA                1.0  self-made         self-made finance
# 1598         CHN                1.0  self-made                 executive
# 1554         CHN                1.0  self-made       founder non-finance
# 1596      Taiwan                1.0  self-made                 executive
# 904          CHN                1.0  self-made       founder non-finance
# 370          CHN                1.0  self-made                 executive
#
#       gender   age   ...    relationshiptocompany foundingdate gdpcurrentus  \
# 184     male  58.0   ...                  founder       1975.0          NaN
# 226     male  74.0   ...                  founder       1990.0          NaN
# 79      male  77.0   ...                  founder       1975.0          NaN
# 1562    male  83.0   ...                  founder       1839.0          NaN
# 862     male  69.0   ...                  founder       1977.0          NaN
# 339     male  73.0   ...                 relation       1940.0          NaN
# 247     male  78.0   ...                 relation       1940.0          NaN
# 1364    male  80.0   ...                  founder       1952.0          NaN
# 280   female  59.0   ...                 relation       1962.0          NaN
# 724     male  66.0   ...                 relation       1962.0          NaN
# 918   female  91.0   ...                 relation       1909.0          NaN
# 1395    male  66.0   ...                 relation       1947.0          NaN
# 67    female  64.0   ...                 relation       1962.0          NaN
# 1322    male  70.0   ...                 relation       1962.0          NaN
# 173     male  64.0   ...                  founder       1987.0          NaN
# 1031    male  72.0   ...                  founder       1981.0          NaN
# 863     male  40.0   ...                  founder       1998.0          NaN
# 700     male  50.0   ...                  founder       1995.0          NaN
# 1354    male  40.0   ...                  founder       1998.0          NaN
# 906     male  85.0   ...                  founder       1950.0          NaN
# 1004    male  29.0   ...                  founder       2004.0          NaN
# 1056    male  88.0   ...                 relation       1946.0          NaN
# 815     male  94.0   ...                 relation       1914.0          NaN
# 70      male  56.0   ...          founder and CEO       1981.0          NaN
# 216     male  78.0   ...                  founder       1968.0          NaN
# 508     male  83.0   ...                  founder       1969.0          NaN
# 349     male  56.0   ...                 relation       1934.0          NaN
# 954     male  84.0   ...         founder/chairman       1955.0          NaN
# 365     male  74.0   ...                 relation       1930.0          NaN
# 1206    male  58.0   ...                  founder       1980.0          NaN
# ...      ...   ...   ...                      ...          ...          ...
# 920     male  86.0   ...                  founder       1996.0          NaN
# 1086  female  75.0   ...                 relation       1948.0          NaN
# 111     male  86.0   ...                  founder       1955.0          NaN
# 156     male  72.0   ...                  founder       1975.0          NaN
# 82      male  65.0   ...                  founder       1992.0          NaN
# 1310    male  49.0   ...                 investor       1999.0          NaN
# 1497  female  47.0   ...                  founder       2004.0          NaN
# 209     male  64.0   ...                  founder       1984.0          NaN
# 371     male  43.0   ...                 director       1966.0          NaN
# 923     male  64.0   ...                    owner       1998.0          NaN
# 485     male  56.0   ...                 chairman       1990.0          NaN
# 376     male  50.0   ...                  founder       1993.0          NaN
# 727     male  48.0   ...                  founder       1993.0          NaN
# 380     male  49.0   ...                  founder       1993.0          NaN
# 1609    male  53.0   ...                 chairman          NaN          NaN
# 195     male  49.0   ...                  founder       1995.0          NaN
# 698   female  77.0   ...                 relation       1968.0          NaN
# 1398    male  50.0   ...                 relation       1948.0          NaN
# 1336  female  43.0   ...                  founder       2000.0          NaN
# 636   female  60.0   ...                 relation       1962.0          NaN
# 936   female  59.0   ...                 investor       1990.0          NaN
# 567     male  63.0   ...            Vice Chairman       1986.0          NaN
# 456     male  53.0   ...                  founder       1989.0          NaN
# 539     male  69.0   ...                  founder       1983.0          NaN
# 891     male  72.0   ...                 investor       1980.0          NaN
# 1598    male   NaN   ...                    owner       1999.0          NaN
# 1554    male  63.0   ...                  founder       1999.0          NaN
# 1596    male  55.0   ...                 investor       1991.0          NaN
# 904     male  64.0   ...                  founder       1989.0          NaN
# 370     male  50.0   ...          deputy chairman       1994.0          NaN
#
#                        sourceofwealth  \
# 184                         Microsoft
# 226                           telecom
# 79                             retail
# 1562               Berkshire Hathaway
# 862                            Oracle
# 339                       diversified
# 247                       diversified
# 1364                          casinos
# 280                          Wal-Mart
# 724                          Wal-Mart
# 918                           L'Oreal
# 1395                              H&M
# 67                           Wal-Mart
# 1322                         Wal-Mart
# 173                              LVMH
# 1031                     Bloomberg LP
# 863                            Google
# 700                        Amazon.com
# 1354                           Google
# 906                       diversified
# 1004                         Facebook
# 1056                       chocolates
# 815                            retail
# 70               cement, sugar, flour
# 216                       investments
# 508                       hedge funds
# 349                             media
# 954                           casinos
# 365                            retail
# 1206                      investments
# ...                               ...
# 920                          palm oil
# 1086                       publishing
# 111                       real estate
# 156                        healthcare
# 82                    pharmaceuticals
# 1310             telecom, investments
# 1497                          fashion
# 209                              beer
# 371                            retail
# 923                            retail
# 485                       diversified
# 376                            retail
# 727                       real estate
# 380                            retail
# 1609                      real estate
# 195                        Hedge fund
# 698            animal pharmaceuticals
# 1398                       publishing
# 1336                            Spanx
# 636                           casinos
# 936                appliance retailer
# 567                       commodities
# 456   copper processing & real estate
# 539                  furniture retail
# 891                       real estate
# 1598                   infant formula
# 1554                auto distribution
# 1596                    manufacturing
# 904                      agribusiness
# 370                             shoes
#
#                                                   notes  \
# 184                                                 NaN
# 226                                                 NaN
# 79                                                  NaN
# 1562                                                NaN
# 862                                                 NaN
# 339                               inherited from father
# 247                               inherited from father
# 1364                                                NaN
# 280                                               widow
# 724                               inherited from father
# 918                               inherited from father
# 1395                              inherited from father
# 67                                inherited from father
# 1322                              inherited from father
# 173                                                 NaN
# 1031                                                NaN
# 863                                                 NaN
# 700                                                 NaN
# 1354                                                NaN
# 906   (Made money because real estate price fell aft...
# 1004                                                NaN
# 1056  relauched father's initial recepie for  hazeln...
# 815   (split from Aldi Nord in 1966, but both branch...
# 70                                                  NaN
# 216                                                 NaN
# 508   (made money by speculating against pound durin...
# 349                               inherited from father
# 954                                                 NaN
# 365                               inherited from father
# 1206                       member of Saudi Royal family
# ...                                                 ...
# 920                                                 NaN
# 1086                              inherited from father
# 111                                                 NaN
# 156                                                 NaN
# 82                                                  NaN
# 1310                                                NaN
# 1497                                                NaN
# 209                                                 NaN
# 371                                                 NaN
# 923                                                 NaN
# 485                                                 NaN
# 376                                                 NaN
# 727                                                 NaN
# 380                                                 NaN
# 1609                                                NaN
# 195                                                 NaN
# 698                                               widow
# 1398                              inherited from father
# 1336                                                NaN
# 636                                            3rd wife
# 936                                                 NaN
# 567                                                 NaN
# 456                                                 NaN
# 539                                                 NaN
# 891                                                 NaN
# 1598                                                NaN
# 1554                                                NaN
# 1596                                                NaN
# 904                                                 NaN
# 370                                                 NaN
#
#                                         notes2  \
# 184                                        NaN
# 226                                        NaN
# 79                                         NaN
# 1562                                       NaN
# 862                                        NaN
# 339                                        NaN
# 247                                        NaN
# 1364                                       NaN
# 280                                        NaN
# 724                                        NaN
# 918                                        NaN
# 1395                                       NaN
# 67                                         NaN
# 1322                                       NaN
# 173                                        NaN
# 1031                                       NaN
# 863                                        NaN
# 700                                        NaN
# 1354                                       NaN
# 906                                        NaN
# 1004                                       NaN
# 1056                                       NaN
# 815   took over mother's single grocerty store
# 70                                         NaN
# 216                                        NaN
# 508                                        NaN
# 349                                 oldest son
# 954                                        NaN
# 365                                        NaN
# 1206                                       NaN
# ...                                        ...
# 920                                        NaN
# 1086                                       NaN
# 111                                        NaN
# 156                                        NaN
# 82                                         NaN
# 1310                                       NaN
# 1497                                       NaN
# 209                                        NaN
# 371                                        NaN
# 923                                        NaN
# 485                                        NaN
# 376                                        NaN
# 727                                        NaN
# 380                                        NaN
# 1609                                       NaN
# 195                                        NaN
# 698                                        NaN
# 1398                                       NaN
# 1336                                       NaN
# 636                                        NaN
# 936                                        NaN
# 567                                        NaN
# 456                                        NaN
# 539                                        NaN
# 891                                        NaN
# 1598                                       NaN
# 1554                                       NaN
# 1596                                       NaN
# 904                                        NaN
# 370                                        NaN
#
#                                                  source  \
# 184           http://www.forbes.com/profile/bill-gates/
# 226   http://www.ozy.com/provocateurs/carlos-slims-w...
# 79        http://www.forbes.com/profile/amancio-ortega/
# 1562  http://www.forbes.com/lists/2009/10/billionair...
# 862        http://www.forbes.com/profile/larry-ellison/
# 339   http://www.kochind.com/About_Koch/History_Time...
# 247   http://www.kochind.com/About_Koch/History_Time...
# 1364     http://www.forbes.com/profile/sheldon-adelson/
# 280       http://www.forbes.com/profile/christy-walton/
# 724           http://www.forbes.com/profile/jim-walton/
# 918   http://www.forbes.com/profile/liliane-bettenco...
# 1395      http://www.forbes.com/profile/stefan-persson/
# 67    http://www.forbes.com/profile/nancy-walton-lau...
# 1322     http://www.forbes.com/profile/s-robson-walton/
# 173      http://www.forbes.com/profile/bernard-arnault/
# 1031  http://www.bloomberg.com/company/bloomberg-fac...
# 863           http://www.forbes.com/profile/larry-page/
# 700   http://www.businessinsider.com/amazon-jeff-bez...
# 1354          http://www.forbes.com/profile/larry-page/
# 906         http://www.ckh.com.hk/en/about/chairman.php
# 1004     http://www.forbes.com/profile/mark-zuckerberg/
# 1056           http://en.wikipedia.org/wiki/Ferrero_SpA
# 815          http://en.wikipedia.org/wiki/Karl_Albrecht
# 70           http://en.wikipedia.org/wiki/Aliko_Dangote
# 216             http://en.wikipedia.org/wiki/Carl_Icahn
# 508           http://en.wikipedia.org/wiki/George_Soros
# 349   http://en.wikipedia.org/wiki/David_Thomson,_3r...
# 954   http://www.ft.com/intl/cms/s/0/492a829c-94a8-1...
# 365       http://www.forbes.com/profile/dieter-schwarz/
# 1206         http://www.kingdom.com.sa/about-us/history
# ...                                                 ...
# 920   http://www.forbes.com/profile/lim-hariyanto-wi...
# 1086    http://www.forbes.com/profile/monika-schoeller/
# 111        http://en.wikipedia.org/wiki/Andrew_Gotianun
# 156           http://en.wikipedia.org/wiki/B._R._Shetty
# 82               http://www.forbes.com/profile/an-kang/
# 1310        http://www.forbes.com/profile/rostam-azizi/
# 1497  http://en.wikipedia.org/wiki/J._Christopher_Burch
# 209    http://en.wikipedia.org/wiki/Samuel_Adams_(beer)
# 371                  http://www.sce-re.com/en/about.asp
# 923      http://www.forbes.com/profile/lin-ming-hsiung/
# 485              http://www.forbes.com/profile/fu-kwan/
# 376       http://www.forbes.com/profile/dmitry-korzhev/
# 727     http://www.forbes.com/profile/jitendra-virwani/
# 380      http://www.forbes.com/profile/dmitry-troitsky/
# 1609           http://www.forbes.com/profile/yang-keng/
# 195      http://www.forbes.com/profile/brian-higgins-1/
# 698         http://www.forbes.com/profile/jeanine-dick/
# 1398    http://www.forbes.com/profile/monika-schoeller/
# 1336                 http://en.wikipedia.org/wiki/Spanx
# 636             http://www.forbes.com/profile/ina-chan/
# 936         http://www.forbes.com/profile/liu-xiaomeng/
# 567    http://en.wikipedia.org/wiki/Noble_Group_Limited
# 456        http://www.forbes.com/profile/feng-hailiang/
# 539   http://en.wikipedia.org/wiki/Graham_Kirkham,_B...
# 891         http://www.forbes.com/profile/leon-charney/
# 1598            http://www.forbes.com/profile/wu-xiong/
# 1554         http://www.forbes.com/profile/wang-muqing/
# 1596         http://www.forbes.com/profile/wu-chung-yi/
# 904           http://www.forbes.com/profile/li-denghai/
# 370            http://en.wikipedia.org/wiki/Anta_Sports
#
#                                                source_2  \
# 184                                                 NaN
# 226                                                 NaN
# 79                                                  NaN
# 1562  http://www.forbes.com/companies/berkshire-hath...
# 862   http://www.businessinsider.com/how-larry-ellis...
# 339                                                 NaN
# 247                                                 NaN
# 1364  http://lasvegassun.com/news/1996/nov/26/rat-pa...
# 280                                                 NaN
# 724                                                 NaN
# 918                                                 NaN
# 1395                                                NaN
# 67                                                  NaN
# 1322                                                NaN
# 173   http://www.lvmh.com/group/milestones/1593-to-t...
# 1031                                                NaN
# 863   http://www.businessinsider.com/larry-page-the-...
# 700                                                 NaN
# 1354                                                NaN
# 906                                                 NaN
# 1004                                                NaN
# 1056          http://www.bbc.com/news/business-31477547
# 815   http://www.bloomberg.com/news/articles/2014-07...
# 70    http://www.nigerianobservernews.com/2014/12/23...
# 216   http://www.bloomberg.com/research/stocks/priva...
# 508   http://www.bloomberg.com/research/stocks/priva...
# 349        http://www.forbes.com/profile/david-thomson/
# 954     http://www.kwah.com/aboutus_process.php?lang=en
# 365                                                 NaN
# 1206  Murdoch's saviour: a rich prince Australian Fi...
# ...                                                 ...
# 920          http://en.wikipedia.org/wiki/Bumitama_Agri
# 1086                                                NaN
# 111      http://www.forbes.com/profile/andrew-gotianun/
# 156              http://www.nmchealth.com/dr-br-shetty/
# 82    http://english.hualanbio.com/enterhualan/history/
# 1310      http://en.wikipedia.org/wiki/Vodacom_Tanzania
# 1497  http://www.vanityfair.com/news/2007/02/tory-bu...
# 209   SAM ADAMS CREATOR THRIVES AMID CRAFT BEER SURG...
# 371        http://www.forbes.com/profile/ding-shizhong/
# 923   http://www.taipeitimes.com/News/taiwan/archive...
# 485        http://www.macrolink.com.cn/en/AboutBig.aspx
# 376   http://www.bloomberg.com/profiles/people/16388...
# 727                                                 NaN
# 380                                                 NaN
# 1609                                                NaN
# 195   http://www.forbes.com/sites/nathanvardi/2014/0...
# 698                                                 NaN
# 1398                                                NaN
# 1336  http://www.wsj.com/articles/a-day-in-the-life-...
# 636                                                 NaN
# 936                                                 NaN
# 567    http://www.forbes.com/profile/harindarpal-banga/
# 456            http://www.hailiang.com/en/about_int.php
# 539       http://www.forbes.com/profile/graham-kirkham/
# 891   Is Now the Right Time for a National Washingto...
# 1598                                                NaN
# 1554     http://www.zhengtongauto.com/en/milestone.html
# 1596  http://en.wikipedia.org/wiki/Tingyi_(Cayman_Is...
# 904                                                 NaN
# 370            http://en.wikipedia.org/wiki/Ding_Shijia
#
#                                                source_3 source_4
# 184                                                 NaN      NaN
# 226                                                 NaN      NaN
# 79                                                  NaN      NaN
# 1562                                                NaN      NaN
# 862                                                 NaN      NaN
# 339                                                 NaN      NaN
# 247                                                 NaN      NaN
# 1364                                                NaN      NaN
# 280                                                 NaN      NaN
# 724                                                 NaN      NaN
# 918                                                 NaN      NaN
# 1395                                                NaN      NaN
# 67                                                  NaN      NaN
# 1322                                                NaN      NaN
# 173                                                 NaN      NaN
# 1031                                                NaN      NaN
# 863                                                 NaN      NaN
# 700                                                 NaN      NaN
# 1354                                                NaN      NaN
# 906                                                 NaN      NaN
# 1004                                                NaN      NaN
# 1056                                                NaN      NaN
# 815         http://aldiuscareers.com/about-aldi/history      NaN
# 70                                                  NaN      NaN
# 216                                                 NaN      NaN
# 508                                                 NaN      NaN
# 349                                                 NaN      NaN
# 954                                                 NaN      NaN
# 365                                                 NaN      NaN
# 1206                                                NaN      NaN
# ...                                                 ...      ...
# 920                                                 NaN      NaN
# 1086                                                NaN      NaN
# 111   Second-hand car dealer discovers road to riche...      NaN
# 156                                                 NaN      NaN
# 82                                                  NaN      NaN
# 1310  http://www.thecitizen.co.tz/News/Rostam--Dewji...      NaN
# 1497                                                NaN      NaN
# 209                                                 NaN      NaN
# 371                                                 NaN      NaN
# 923                                                 NaN      NaN
# 485                                                 NaN      NaN
# 376                                                 NaN      NaN
# 727                                                 NaN      NaN
# 380                                                 NaN      NaN
# 1609                                                NaN      NaN
# 195                                                 NaN      NaN
# 698                                                 NaN      NaN
# 1398                                                NaN      NaN
# 1336                                                NaN      NaN
# 636                                                 NaN      NaN
# 936                                                 NaN      NaN
# 567                                                 NaN      NaN
# 456                                                 NaN      NaN
# 539   http://www.independent.co.uk/news/business/kir...      NaN
# 891                                                 NaN      NaN
# 1598                                                NaN      NaN
# 1554                                                NaN      NaN
# 1596  Tingyi-Campbell sale talks stay on track South...      NaN
# 904                                                 NaN      NaN
# 370   http://www.bloomberg.com/research/stocks/peopl...      NaN
#
# [1653 rows x 30 columns]

# %% [markdown]
# ## 4) How many male billionaires are there compared to the number of female billionares? Do they have a different average wealth?
#
# > **TIP:** The second part uses `groupby`, but the first part does not.

# %%
df['gender'].value_counts() 
#df[df['gender'] == 'female'].describe()
#df[df['gender'] == 'male'].describe()
# Out:
# male      1473
# female     180
# Name: gender, dtype: int64

# %%
df.groupby("gender")['networthusbillion'].mean()
# Out:
# gender
# female    3.920556
# male      3.902716
# Name: networthusbillion, dtype: float64

# %% [markdown]
# ## 5) Who is the poorest billionaire? Who are the top 10 poorest billionaires?

# %%
#df.groupby("gender")['networthusbillion'].describe()
df.sort_values(by="networthusbillion").head(10)
# Out:
#       year               name  rank    citizenship countrycode  \
# 156   2014        B.R. Shetty  1565          India         IND
# 1310  2014       Rostam Azizi  1565       Tanzania         TZA
# 1497  2014         Tory Burch  1565  United States         USA
# 476   2014         Fred Chang  1565  United States         USA
# 115   2014     Angela Bennett  1565      Australia         AUS
# 485   2014            Fu Kwan  1565          China         CHN
# 1318  2014     Ryan Kavanaugh  1565  United States         USA
# 1133  2014  O. Francis Biondi  1565  United States         USA
# 859   2014       Lam Fong Ngo  1565          Macau         MAC
# 456   2014      Feng Hailiang  1565          China         CHN
#
#       networthusbillion   selfmade         typeofwealth  gender   age  \
# 156                 1.0  self-made  founder non-finance    male  72.0
# 1310                1.0  self-made            executive    male  49.0
# 1497                1.0  self-made  founder non-finance  female  47.0
# 476                 1.0  self-made  founder non-finance    male  57.0
# 115                 1.0  inherited            inherited  female  69.0
# 485                 1.0  self-made    self-made finance    male  56.0
# 1318                1.0  self-made  founder non-finance    male  39.0
# 1133                1.0  self-made    self-made finance    male  49.0
# 859                 1.0  self-made    self-made finance  female   NaN
# 456                 1.0  self-made  founder non-finance    male  53.0
#
#        ...    relationshiptocompany foundingdate gdpcurrentus  \
# 156    ...                  founder       1975.0          NaN
# 1310   ...                 investor       1999.0          NaN
# 1497   ...                  founder       2004.0          NaN
# 476    ...                  founder       2001.0          NaN
# 115    ...                 relation       1955.0          NaN
# 485    ...                 chairman       1990.0          NaN
# 1318   ...                  founder       2004.0          NaN
# 1133   ...                  founder       1995.0          NaN
# 859    ...            Vice Chairman       1997.0          NaN
# 456    ...                  founder       1989.0          NaN
#
#                        sourceofwealth                  notes  \
# 156                        healthcare                    NaN
# 1310             telecom, investments                    NaN
# 1497                          fashion                    NaN
# 476                  online retailing                    NaN
# 115                            mining  inherited from father
# 485                       diversified                    NaN
# 1318                           Movies                    NaN
# 1133                       hedge fund                    NaN
# 859                           casinos                    NaN
# 456   copper processing & real estate                    NaN
#
#                            notes2  \
# 156                           NaN
# 1310                          NaN
# 1497                          NaN
# 476                           NaN
# 115   shared fortune with brother
# 485                           NaN
# 1318                          NaN
# 1133                          NaN
# 859                           NaN
# 456                           NaN
#
#                                                  source  \
# 156           http://en.wikipedia.org/wiki/B._R._Shetty
# 1310        http://www.forbes.com/profile/rostam-azizi/
# 1497  http://en.wikipedia.org/wiki/J._Christopher_Burch
# 476                 http://en.wikipedia.org/wiki/Newegg
# 115       http://www.forbes.com/profile/angela-bennett/
# 485              http://www.forbes.com/profile/fu-kwan/
# 1318        http://en.wikipedia.org/wiki/Ryan_Kavanaugh
# 1133    http://www.forbes.com/profile/o-francis-biondi/
# 859         http://www.forbes.com/profile/david-chow-1/
# 456        http://www.forbes.com/profile/feng-hailiang/
#
#                                                source_2  \
# 156              http://www.nmchealth.com/dr-br-shetty/
# 1310      http://en.wikipedia.org/wiki/Vodacom_Tanzania
# 1497  http://www.vanityfair.com/news/2007/02/tory-bu...
# 476           http://www.newegg.com/Info/FactSheet.aspx
# 115                                                 NaN
# 485        http://www.macrolink.com.cn/en/AboutBig.aspx
# 1318      http://en.wikipedia.org/wiki/Relativity_Media
# 1133  http://www.forbes.com/sites/nathanvardi/2014/0...
# 859   http://www.macaulegend.com/html/about_mileston...
# 456            http://www.hailiang.com/en/about_int.php
#
#                                                source_3 source_4
# 156                                                 NaN      NaN
# 1310  http://www.thecitizen.co.tz/News/Rostam--Dewji...      NaN
# 1497                                                NaN      NaN
# 476   http://www.forbes.com/sites/andreanavarro/2014...      NaN
# 115                                                 NaN      NaN
# 485                                                 NaN      NaN
# 1318  http://www.vanityfair.com/news/2010/03/kavanau...      NaN
# 1133                                                NaN      NaN
# 859   Macau Legend to roll the dice on HK IPO; But l...      NaN
# 456                                                 NaN      NaN
#
# [10 rows x 30 columns]

# %% [markdown]
# ## 6) What is the most common source of wealth? Is it different between males and females?
#
# > **TIP:** You know how to `groupby` and you know how to count how many times a value is in a column. Can you put them together???

# %%
df.sort_values(by="typeofwealth")
df.groupby("gender")['typeofwealth'].value_counts()

#1 - most common types of wealth is "inherited" and "founder non-finance"
# --> sourceofwealth could also be used
#2 - Yes, there is a difference between women and men
# Out:
# gender  typeofwealth
# female  inherited                   142
#         founder non-finance          21
#         executive                     6
#         self-made finance             6
#         privatized and resources      5
# male    founder non-finance         446
#         inherited                   364
#         self-made finance           338
#         privatized and resources    187
#         executive                   136
# Name: typeofwealth, dtype: int64

# %%
df[df["gender"] == "female"]["sourceofwealth"].value_counts().head(10)
# Out:
# diversified            9
# real estate            7
# media                  6
# hotels, investments    5
# consumer goods         5
# construction           5
# chemicals              4
# casinos                4
# cleaning products      4
# Wal-Mart               4
# Name: sourceofwealth, dtype: int64

# %%
df[df["gender"] == "male"]["sourceofwealth"].value_counts().head(10)
# Out:
# real estate        100
# retail              60
# diversified         60
# investments         58
# pharmaceuticals     40
# hedge funds         34
# banking             30
# construction        27
# media               18
# software            18
# Name: sourceofwealth, dtype: int64

# %% [markdown]
# ## 7) What companies have the most billionaires? Graph the top 5 as a horizontal bar graph.
#
# > **TIP:** First find the answer to the question, then just try to throw `.plot()` on the end
# >
# > **TIP:** You can use `.head()` on *anything*, not just your basic `df`
# >
# > **TIP:** You might feel like oyu should use `groupby`, but don't! There's an easier way to count.

# %%
df['company'].value_counts().head().plot(kind='barh')

# %% [markdown]
# ## 8) How much money do these billionaires have in total?

# %%
df['networthusbillion'].sum()
# Out:
# 6454.4000000000005

# %% [markdown]
# ## 9) What are the top 3 countries with the most money held by billionaires?
#
# I am **not** asking which country has the most billionaires - this is total amount of money per country.
#
# > **TIP:** Think about it in steps - "I want them organized by country," "I want their net worth," and "I want to add it all up." Just chain them all together.

# %%
df.groupby("citizenship")['networthusbillion'].sum().sort_values(ascending=False).head(3)
# Out:
# citizenship
# United States    2322.4
# Russia            422.5
# Germany           401.4
# Name: networthusbillion, dtype: float64

# %% [markdown]
# ## 10) How old is an average billionaire? How old are billionaires self made vs. non self made?

# %%
df["age"].mean()
# Out:
# 63.342138364779878

# %%
df.groupby("selfmade")["age"].mean() 
#df[['age', 'selfmade']]
# Out:
# selfmade
# inherited    64.962185
# self-made    62.625899
# Name: age, dtype: float64

# %% [markdown]
# ## 11) Who are the youngest billionaires? Who are the oldest? Make a graph of the distribution of ages.

# %%
df.sort_values(by="age").head(1)
# Out:
#       year         name  rank citizenship countrycode  networthusbillion  \
# 1172  2014  Perenna Kei  1284   Hong Kong         HKG                1.3
#
#        selfmade typeofwealth  gender   age   ...    relationshiptocompany  \
# 1172  inherited    inherited  female  24.0   ...                 relation
#
#      foundingdate gdpcurrentus  sourceofwealth                  notes  notes2  \
# 1172       1996.0          NaN     real estate  inherited from father     NaN
#
#                                         source  \
# 1172  http://en.wikipedia.org/wiki/Perenna_Kei
#
#                                                source_2 source_3 source_4
# 1172  http://www.loganestate.com/en/about.aspx?ftid=294      NaN      NaN
#
# [1 rows x 30 columns]

# %%
df.sort_values(by="age").tail(1)
# Out:
#       year      name  rank citizenship countrycode  networthusbillion  \
# 1598  2014  Wu Xiong  1565       China         CHN                1.0
#
#        selfmade typeofwealth gender  age   ...    relationshiptocompany  \
# 1598  self-made    executive   male  NaN   ...                    owner
#
#      foundingdate gdpcurrentus  sourceofwealth  notes  notes2  \
# 1598       1999.0          NaN  infant formula    NaN     NaN
#
#                                        source source_2 source_3 source_4
# 1598  http://www.forbes.com/profile/wu-xiong/      NaN      NaN      NaN
#
# [1 rows x 30 columns]

# %%
df['age'].hist()

# %% [markdown]
# ## 12) Make a scatterplot of their net worth compared to their age

# %%
df.plot(kind='scatter', x='age', y='networthusbillion')

# %% [markdown]
# ## 13) Make a bar graph of the top 10 richest billionaires

# %%
df.sort_values(by="networthusbillion", ascending=False).head(10).plot(kind='barh', x='name', y='networthusbillion')
